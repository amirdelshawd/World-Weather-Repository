# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Import the dataset
data = pd.read_csv("/content/GlobalWeatherRepository.csv")

# %%
# Display the first 5 rows
print(data.head())
# Out:
#        country     location_name  latitude  longitude        timezone  \
# 0  Afghanistan             Kabul     34.52      69.18      Asia/Kabul
# 1      Albania            Tirana     41.33      19.82   Europe/Tirane
# 2      Algeria           Algiers     36.76       3.05  Africa/Algiers
# 3      Andorra  Andorra La Vella     42.50       1.52  Europe/Andorra
# 4       Angola            Luanda     -8.84      13.23   Africa/Luanda
#
#    last_updated_epoch      last_updated  temperature_celsius  \
# 0          1693301400  2023-08-29 14:00                 28.8
# 1          1693301400  2023-08-29 11:30                 27.0
# 2          1693301400  2023-08-29 10:30                 28.0
# 3          1693301400  2023-08-29 11:30                 10.2
# 4          1693301400  2023-08-29 10:30                 25.0
#
#    temperature_fahrenheit condition_text  ...  air_quality_PM2.5  \
# 0                    83.8          Sunny  ...                7.9
# ...

# %%
# Optionally: Display some basic statistics or visualize the data
data.describe()
# Out:
#           latitude    longitude  last_updated_epoch  temperature_celsius  \
# count  5841.000000  5841.000000        5.841000e+03          5841.000000
# mean     19.304525    21.888677        1.694518e+09            22.450009
# std      24.584199    65.635293        7.432707e+05             6.603811
# min     -41.300000  -175.200000        1.693301e+09            -2.000000
# 25%       3.750000    -6.840000        1.693870e+09            17.800000
# 50%      17.250000    23.240000        1.694473e+09            23.000000
# 75%      41.330000    50.580000        1.695163e+09            27.200000
# max      63.830000   179.220000        1.695766e+09            45.000000
#
#        temperature_fahrenheit     wind_mph     wind_kph  wind_degree  \
# count             5841.000000  5841.000000  5841.000000  5841.000000
# mean                72.410426     6.650437    10.703047   161.490156
# std                 11.887032     4.699120     7.564145   103.707308
# ...

# %%
# If it's suitable for a plot:
data.plot()
plt.show()
